# %% [markdown]
# 安装所需的库

# %%
# Main Package
# %pip install Agently
# Requirement Packages
## Network
# %pip install aiohttp
# %pip install websockets
# %pip install tornado
## Model Clients
# %pip install openai
# %pip install httpx
# %pip install erniebot
# %pip install zhipuai
## Data Format
# %pip install PyYAML
# Out:
# Collecting Agently
#   Downloading Agently-3.0.5.post3.tar.gz (43 kB)
#      ---------------------------------------- 0.0/43.2 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.2 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.2 kB ? eta -:--:--
#      --------- ------------------------------ 10.2/43.2 kB ? eta -:--:--
#      ------------------ -------------------- 20.5/43.2 kB 59.5 kB/s eta 0:00:01
#      -------------------------------------- 43.2/43.2 kB 175.2 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: aiohttp in d:\anaconda\lib\site-packages (from Agently) (3.8.3)
# Collecting websockets (from Agently)
#   Obtaining dependency information for websockets from https://files.pythonhosted.org/packages/d1/40/6b169cd1957476374f51f4486a3e85003149e62a14e6b78a958c2222337a/websockets-12.0-cp311-cp311-win_amd64.whl.metadata
#   Downloading websockets-12.0-cp311-cp311-win_amd64.whl.metadata (6.8 kB)
# Requirement already satisfied: tornado in d:\anaconda\lib\site-packages (from Agently) (6.3.2)
# Collecting openai (from Agently)
#   Obtaining dependency information for openai from https://files.pythonhosted.org/packages/b5/db/057823642344c26a8cbc54dabe2e9f3a1047a3fb0df75c8e3a80e35191b7/openai-1.3.9-py3-none-any.whl.metadata
#   Downloading openai-1.3.9-py3-none-any.whl.metadata (17 kB)
# Collecting httpx (from Agently)
#   Obtaining dependency information for httpx from https://files.pythonhosted.org/packages/a2/65/6940eeb21dcb2953778a6895281c179efd9100463ff08cb6232bb6480da7/httpx-0.25.2-py3-none-any.whl.metadata
#   Downloading httpx-0.25.2-py3-none-any.whl.metadata (6.9 kB)
# Collecting erniebot (from Agently)
#   Obtaining dependency information for erniebot from https://files.pythonhosted.org/packages/29/35/dd43f7c14a7ed1bafaaa64aacaad0e9ed7072f7509e710858ac853eb3663/erniebot-0.4.0-py3-none-any.whl.metadata
#   Downloading erniebot-0.4.0-py3-none-any.whl.metadata (9.9 kB)
# Collecting zhipuai (from Agently)
#   Obtaining dependency information for zhipuai from https://files.pythonhosted.org/packages/a5/b5/cb50cd478426b17503154585be799e09506b70944e2fe2402aa029987fa2/zhipuai-1.0.7-py3-none-any.whl.metadata
#   Downloading zhipuai-1.0.7-py3-none-any.whl.metadata (586 bytes)
# Requirement already satisfied: PyYAML in d:\anaconda\lib\site-packages (from Agently) (6.0)
# Collecting duckduckgo_search (from Agently)
#   Obtaining dependency information for duckduckgo_search from https://files.pythonhosted.org/packages/9d/f3/c7c66f0e767861c4d3105f11a5cd2ec7219f72c710bd766d9b4930e92b81/duckduckgo_search-4.1.0-py3-none-any.whl.metadata
#   Downloading duckduckgo_search-4.1.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (22.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp->Agently) (1.2.0)
# Collecting click>=8.1.7 (from duckduckgo_search->Agently)
#   Obtaining dependency information for click>=8.1.7 from https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl.metadata
#   Using cached click-8.1.7-py3-none-any.whl.metadata (3.0 kB)
# Collecting lxml>=4.9.3 (from duckduckgo_search->Agently)
#   Obtaining dependency information for lxml>=4.9.3 from https://files.pythonhosted.org/packages/31/58/e3b3dd6bb2ab7404f1f4992e2d0e6926ed40cef8ce1b3bbefd95877499e1/lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata
#   Downloading lxml-4.9.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Collecting curl-cffi>=0.5.10 (from duckduckgo_search->Agently)
#   Obtaining dependency information for curl-cffi>=0.5.10 from https://files.pythonhosted.org/packages/4e/70/0d4d667287d54cb4daf8ce67068565c8e09e4f839a835119cd27f229a446/curl_cffi-0.5.10-cp37-abi3-win_amd64.whl.metadata
#   Downloading curl_cffi-0.5.10-cp37-abi3-win_amd64.whl.metadata (8.1 kB)
# Collecting bce-python-sdk (from erniebot->Agently)
#   Obtaining dependency information for bce-python-sdk from https://files.pythonhosted.org/packages/0d/8e/a5e4d584c226e9eed2ea12334b8bc83dca53313c9ed35c6837b1f0ad772c/bce_python_sdk-0.8.97-py3-none-any.whl.metadata
#   Downloading bce_python_sdk-0.8.97-py3-none-any.whl.metadata (319 bytes)
# Collecting colorlog (from erniebot->Agently)
#   Obtaining dependency information for colorlog from https://files.pythonhosted.org/packages/95/df/520663eb7f7a329f7c585834b754bcc3cbcc03957d85fcbba4a2a723ad9d/colorlog-6.8.0-py3-none-any.whl.metadata
#   Downloading colorlog-6.8.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema>=4.19 (from erniebot->Agently)
#   Obtaining dependency information for jsonschema>=4.19 from https://files.pythonhosted.org/packages/0f/ed/0058234d8dd2b1fc6beeea8eab945191a05e9d391a63202f49fe23327586/jsonschema-4.20.0-py3-none-any.whl.metadata
#   Downloading jsonschema-4.20.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: requests>=2.20 in d:\anaconda\lib\site-packages (from erniebot->Agently) (2.31.0)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from erniebot->Agently) (4.7.1)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx->Agently) (3.5.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx->Agently) (2023.7.22)
# Collecting httpcore==1.* (from httpx->Agently)
#   Obtaining dependency information for httpcore==1.* from https://files.pythonhosted.org/packages/56/ba/78b0a99c4da0ff8b0f59defa2f13ca4668189b134bd9840b6202a93d9a0f/httpcore-1.0.2-py3-none-any.whl.metadata
#   Downloading httpcore-1.0.2-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx->Agently) (3.4)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from httpx->Agently) (1.2.0)
# Collecting h11<0.15,>=0.13 (from httpcore==1.*->httpx->Agently)
#   Using cached h11-0.14.0-py3-none-any.whl (58 kB)
# Collecting distro<2,>=1.7.0 (from openai->Agently)
#   Downloading distro-1.8.0-py3-none-any.whl (20 kB)
# Collecting pydantic<3,>=1.9.0 (from openai->Agently)
#   Obtaining dependency information for pydantic<3,>=1.9.0 from https://files.pythonhosted.org/packages/0a/2b/64066de1c4cf3d4ed623beeb3bbf3f8d0cc26661f1e7d180ec5eb66b75a5/pydantic-2.5.2-py3-none-any.whl.metadata
#   Downloading pydantic-2.5.2-py3-none-any.whl.metadata (65 kB)
#      ---------------------------------------- 0.0/65.2 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/65.2 kB ? eta -:--:--
#      ----------------- -------------------- 30.7/65.2 kB 640.0 kB/s eta 0:00:01
#      -------------------------------------- 65.2/65.2 kB 584.8 kB/s eta 0:00:00
# Requirement already satisfied: tqdm>4 in d:\anaconda\lib\site-packages (from openai->Agently) (4.65.0)
# Requirement already satisfied: PyJWT in d:\anaconda\lib\site-packages (from zhipuai->Agently) (2.4.0)
# Collecting dataclasses (from zhipuai->Agently)
#   Using cached dataclasses-0.6-py3-none-any.whl (14 kB)
# Collecting cachetools (from zhipuai->Agently)
#   Obtaining dependency information for cachetools from https://files.pythonhosted.org/packages/a2/91/2d843adb9fbd911e0da45fbf6f18ca89d07a087c3daa23e955584f90ebf4/cachetools-5.3.2-py3-none-any.whl.metadata
#   Downloading cachetools-5.3.2-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from click>=8.1.7->duckduckgo_search->Agently) (0.4.6)
# Requirement already satisfied: cffi>=1.12.0 in d:\anaconda\lib\site-packages (from curl-cffi>=0.5.10->duckduckgo_search->Agently) (1.15.1)
# Collecting attrs>=17.3.0 (from aiohttp->Agently)
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=4.19->erniebot->Agently)
#   Obtaining dependency information for jsonschema-specifications>=2023.03.6 from https://files.pythonhosted.org/packages/d7/48/b62ccba8f4ac91817d6a11b340e63806175dafb10234a8cf7140bd389da5/jsonschema_specifications-2023.11.2-py3-none-any.whl.metadata
#   Downloading jsonschema_specifications-2023.11.2-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=4.19->erniebot->Agently)
#   Obtaining dependency information for referencing>=0.28.4 from https://files.pythonhosted.org/packages/b4/11/d121780c173336c9bc3a5b8240ed31f518957cc22f6311c76259cb0fcf32/referencing-0.32.0-py3-none-any.whl.metadata
#   Downloading referencing-0.32.0-py3-none-any.whl.metadata (2.7 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=4.19->erniebot->Agently)
#   Obtaining dependency information for rpds-py>=0.7.1 from https://files.pythonhosted.org/packages/96/fc/abf533130478cb02f2e48092c74fddc79524bb215484bd6634d6b772b46c/rpds_py-0.13.2-cp311-none-win_amd64.whl.metadata
#   Downloading rpds_py-0.13.2-cp311-none-win_amd64.whl.metadata (4.0 kB)
# Collecting annotated-types>=0.4.0 (from pydantic<3,>=1.9.0->openai->Agently)
#   Obtaining dependency information for annotated-types>=0.4.0 from https://files.pythonhosted.org/packages/28/78/d31230046e58c207284c6b2c4e8d96e6d3cb4e52354721b944d3e1ee4aa5/annotated_types-0.6.0-py3-none-any.whl.metadata
#   Using cached annotated_types-0.6.0-py3-none-any.whl.metadata (12 kB)
# Collecting pydantic-core==2.14.5 (from pydantic<3,>=1.9.0->openai->Agently)
#   Obtaining dependency information for pydantic-core==2.14.5 from https://files.pythonhosted.org/packages/04/a1/36cea283ded0641e8c374cdcacfdab035c102467ac5ec721b7527c8ac1cf/pydantic_core-2.14.5-cp311-none-win_amd64.whl.metadata
#   Downloading pydantic_core-2.14.5-cp311-none-win_amd64.whl.metadata (6.6 kB)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.20->erniebot->Agently) (1.26.16)
# Collecting pycryptodome>=3.8.0 (from bce-python-sdk->erniebot->Agently)
#   Obtaining dependency information for pycryptodome>=3.8.0 from https://files.pythonhosted.org/packages/87/c4/c979db0914a23541d62c9e4b5e8a30f56a78c6dec8677db6a5327d306be5/pycryptodome-3.19.0-cp35-abi3-win_amd64.whl.metadata
#   Downloading pycryptodome-3.19.0-cp35-abi3-win_amd64.whl.metadata (3.4 kB)
# Requirement already satisfied: future>=0.6.0 in d:\anaconda\lib\site-packages (from bce-python-sdk->erniebot->Agently) (0.18.3)
# Requirement already satisfied: six>=1.4.0 in d:\anaconda\lib\site-packages (from bce-python-sdk->erniebot->Agently) (1.16.0)
# Requirement already satisfied: pycparser in d:\anaconda\lib\site-packages (from cffi>=1.12.0->curl-cffi>=0.5.10->duckduckgo_search->Agently) (2.21)
# Downloading duckduckgo_search-4.1.0-py3-none-any.whl (25 kB)
# Downloading erniebot-0.4.0-py3-none-any.whl (68 kB)
#    ---------------------------------------- 0.0/68.4 kB ? eta -:--:--
#    ----------------- ---------------------- 30.7/68.4 kB 660.6 kB/s eta 0:00:01
#    ---------------------------------------- 68.4/68.4 kB 745.2 kB/s eta 0:00:00
# Downloading httpx-0.25.2-py3-none-any.whl (74 kB)
#    ---------------------------------------- 0.0/75.0 kB ? eta -:--:--
#    ---------------- ----------------------- 30.7/75.0 kB 1.3 MB/s eta 0:00:01
#    ---------------------------------------- 75.0/75.0 kB 830.0 kB/s eta 0:00:00
# Downloading httpcore-1.0.2-py3-none-any.whl (76 kB)
#    ---------------------------------------- 0.0/76.9 kB ? eta -:--:--
#    --------------- ------------------------ 30.7/76.9 kB 1.3 MB/s eta 0:00:01
#    ------------------------------- -------- 61.4/76.9 kB 812.7 kB/s eta 0:00:01
#    ---------------------------------------- 76.9/76.9 kB 844.3 kB/s eta 0:00:00
# Downloading openai-1.3.9-py3-none-any.whl (221 kB)
#    ---------------------------------------- 0.0/221.4 kB ? eta -:--:--
#    ------- ------------------------------- 41.0/221.4 kB 653.6 kB/s eta 0:00:01
#    -------------- ------------------------ 81.9/221.4 kB 919.0 kB/s eta 0:00:01
#    --------------------- ---------------- 122.9/221.4 kB 798.9 kB/s eta 0:00:01
#    ---------------------------- --------- 163.8/221.4 kB 821.4 kB/s eta 0:00:01
#    ----------------------------------- -- 204.8/221.4 kB 888.4 kB/s eta 0:00:01
#    -------------------------------------- 221.4/221.4 kB 902.4 kB/s eta 0:00:00
# Downloading websockets-12.0-cp311-cp311-win_amd64.whl (124 kB)
#    ---------------------------------------- 0.0/125.0 kB ? eta -:--:--
#    ---------------------- ----------------- 71.7/125.0 kB 3.8 MB/s eta 0:00:01
#    ---------------------------------------- 125.0/125.0 kB 2.4 MB/s eta 0:00:00
# Using cached zhipuai-1.0.7-py3-none-any.whl (7.9 kB)
# Using cached click-8.1.7-py3-none-any.whl (97 kB)
# Downloading curl_cffi-0.5.10-cp37-abi3-win_amd64.whl (2.6 MB)
#    ---------------------------------------- 0.0/2.6 MB ? eta -:--:--
#    - -------------------------------------- 0.1/2.6 MB 2.4 MB/s eta 0:00:02
#    --- ------------------------------------ 0.2/2.6 MB 2.4 MB/s eta 0:00:02
#    ----- ---------------------------------- 0.4/2.6 MB 2.5 MB/s eta 0:00:01
#    ------ --------------------------------- 0.5/2.6 MB 2.3 MB/s eta 0:00:01
#    -------- ------------------------------- 0.6/2.6 MB 2.4 MB/s eta 0:00:01
#    ---------- ----------------------------- 0.7/2.6 MB 2.5 MB/s eta 0:00:01
#    ------------ --------------------------- 0.8/2.6 MB 2.5 MB/s eta 0:00:01
#    --------------- ------------------------ 1.0/2.6 MB 2.7 MB/s eta 0:00:01
#    -------------------- ------------------- 1.3/2.6 MB 3.3 MB/s eta 0:00:01
#    ------------------------ --------------- 1.6/2.6 MB 3.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 1.9/2.6 MB 3.8 MB/s eta 0:00:01
#    --------------------------------- ------ 2.2/2.6 MB 4.0 MB/s eta 0:00:01
#    -------------------------------------- - 2.5/2.6 MB 4.3 MB/s eta 0:00:01
#    ---------------------------------------- 2.6/2.6 MB 4.3 MB/s eta 0:00:00
# Downloading jsonschema-4.20.0-py3-none-any.whl (84 kB)
#    ---------------------------------------- 0.0/84.7 kB ? eta -:--:--
#    ---------------------------------------- 84.7/84.7 kB 4.7 MB/s eta 0:00:00
# Using cached lxml-4.9.3-cp311-cp311-win_amd64.whl (3.8 MB)
# Downloading pydantic-2.5.2-py3-none-any.whl (381 kB)
#    ---------------------------------------- 0.0/381.9 kB ? eta -:--:--
#    -------- ------------------------------- 81.9/381.9 kB ? eta -:--:--
#    ---------------------------------------- 381.9/381.9 kB 6.0 MB/s eta 0:00:00
# Downloading pydantic_core-2.14.5-cp311-none-win_amd64.whl (1.9 MB)
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    --- ------------------------------------ 0.2/1.9 MB 9.0 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/1.9 MB 9.0 MB/s eta 0:00:01
#    --- ------------------------------------ 0.2/1.9 MB 9.0 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.2/1.9 MB 1.4 MB/s eta 0:00:02
#    ------------------- -------------------- 0.9/1.9 MB 3.8 MB/s eta 0:00:01
#    ---------------------------------------  1.9/1.9 MB 6.6 MB/s eta 0:00:01
#    ---------------------------------------- 1.9/1.9 MB 6.7 MB/s eta 0:00:00
# Downloading bce_python_sdk-0.8.97-py3-none-any.whl (241 kB)
#    ---------------------------------------- 0.0/241.5 kB ? eta -:--:--
#    -------------------- ------------------- 122.9/241.5 kB 7.0 MB/s eta 0:00:01
#    ----------------------- ---------------- 143.4/241.5 kB 2.1 MB/s eta 0:00:01
#    ---------------------------------------- 241.5/241.5 kB 2.1 MB/s eta 0:00:00
# Using cached cachetools-5.3.2-py3-none-any.whl (9.3 kB)
# Downloading colorlog-6.8.0-py3-none-any.whl (11 kB)
# Using cached annotated_types-0.6.0-py3-none-any.whl (12 kB)
# Downloading jsonschema_specifications-2023.11.2-py3-none-any.whl (17 kB)
# Downloading pycryptodome-3.19.0-cp35-abi3-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    -- ------------------------------------- 0.1/1.7 MB 7.5 MB/s eta 0:00:01
#    ---------------------- ----------------- 1.0/1.7 MB 2.9 MB/s eta 0:00:01
#    ---------------------------------------  1.7/1.7 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 1.7/1.7 MB 4.6 MB/s eta 0:00:00
# Downloading referencing-0.32.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.13.2-cp311-none-win_amd64.whl (188 kB)
#    ---------------------------------------- 0.0/188.7 kB ? eta -:--:--
#    ----------------------- ---------------- 112.6/188.7 kB 3.2 MB/s eta 0:00:01
#    ---------------------------------------- 188.7/188.7 kB 1.9 MB/s eta 0:00:00
# Building wheels for collected packages: Agently
#   Building wheel for Agently (setup.py): started
#   Building wheel for Agently (setup.py): finished with status 'done'
#   Created wheel for Agently: filename=Agently-3.0.5.post3-py3-none-any.whl size=59891 sha256=5682b707a7a3d555a8a888c156352f6e95e16e82d118b51e7088a76244a00f20
#   Stored in directory: c:\users\administrator\appdata\local\pip\cache\wheels\48\b0\2a\06098d1431d046b4d4965e3367edc11f1e81e4544df21ca5fc
# Successfully built Agently
# Installing collected packages: dataclasses, websockets, rpds-py, pydantic-core, pycryptodome, lxml, h11, distro, colorlog, click, cachetools, attrs, annotated-types, zhipuai, referencing, pydantic, httpcore, curl-cffi, bce-python-sdk, jsonschema-specifications, httpx, duckduckgo_search, openai, jsonschema, erniebot, Agently
#   Attempting uninstall: lxml
#     Found existing installation: lxml 4.9.2
#     Uninstalling lxml-4.9.2:
#       Successfully uninstalled lxml-4.9.2
#   Attempting uninstall: click
#     Found existing installation: click 8.0.4
#     Uninstalling click-8.0.4:
#       Successfully uninstalled click-8.0.4
#   Attempting uninstall: attrs
#     Found existing installation: attrs 22.1.0
#     Uninstalling attrs-22.1.0:
#       Successfully uninstalled attrs-22.1.0
#   Attempting uninstall: jsonschema
#     Found existing installation: jsonschema 4.17.3
#     Uninstalling jsonschema-4.17.3:
#       Successfully uninstalled jsonschema-4.17.3
# Successfully installed Agently-3.0.5.post3 annotated-types-0.6.0 attrs-23.1.0 bce-python-sdk-0.8.97 cachetools-5.3.2 click-8.1.7 colorlog-6.8.0 curl-cffi-0.5.10 dataclasses-0.6 distro-1.8.0 duckduckgo_search-4.1.0 erniebot-0.4.0 h11-0.14.0 httpcore-1.0.2 httpx-0.25.2 jsonschema-4.20.0 jsonschema-specifications-2023.11.2 lxml-4.9.3 openai-1.3.9 pycryptodome-3.19.0 pydantic-2.5.2 pydantic-core-2.14.5 referencing-0.32.0 rpds-py-0.13.2 websockets-12.0 zhipuai-1.0.7
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.15.0 requires gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1, which is not installed.
# python-lsp-black 1.2.1 requires black>=22.3.0, but you have black 0.0 which is incompatible.
# s3fs 2023.3.0 requires fsspec==2023.3.0, but you have fsspec 2023.6.0 which is incompatible.
# Requirement already satisfied: aiohttp in d:\anaconda\lib\site-packages (3.8.3)
# Requirement already satisfied: attrs>=17.3.0 in d:\anaconda\lib\site-packages (from aiohttp) (23.1.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in d:\anaconda\lib\site-packages (from aiohttp) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda\lib\site-packages (from aiohttp) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp) (1.2.0)
# Requirement already satisfied: idna>=2.0 in d:\anaconda\lib\site-packages (from yarl<2.0,>=1.0->aiohttp) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: websockets in d:\anaconda\lib\site-packages (12.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tornado in d:\anaconda\lib\site-packages (6.3.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: openai in d:\anaconda\lib\site-packages (1.3.9)
# Requirement already satisfied: anyio<5,>=3.5.0 in d:\anaconda\lib\site-packages (from openai) (3.5.0)
# Requirement already satisfied: distro<2,>=1.7.0 in d:\anaconda\lib\site-packages (from openai) (1.8.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in d:\anaconda\lib\site-packages (from openai) (0.25.2)
# Requirement already satisfied: pydantic<3,>=1.9.0 in d:\anaconda\lib\site-packages (from openai) (2.5.2)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from openai) (1.2.0)
# Requirement already satisfied: tqdm>4 in d:\anaconda\lib\site-packages (from openai) (4.65.0)
# Requirement already satisfied: typing-extensions<5,>=4.5 in d:\anaconda\lib\site-packages (from openai) (4.7.1)
# Requirement already satisfied: idna>=2.8 in d:\anaconda\lib\site-packages (from anyio<5,>=3.5.0->openai) (3.4)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx<1,>=0.23.0->openai) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: annotated-types>=0.4.0 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (0.6.0)
# Requirement already satisfied: pydantic-core==2.14.5 in d:\anaconda\lib\site-packages (from pydantic<3,>=1.9.0->openai) (2.14.5)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from tqdm>4->openai) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: httpx in d:\anaconda\lib\site-packages (0.25.2)
# Requirement already satisfied: anyio in d:\anaconda\lib\site-packages (from httpx) (3.5.0)
# Requirement already satisfied: certifi in d:\anaconda\lib\site-packages (from httpx) (2023.7.22)
# Requirement already satisfied: httpcore==1.* in d:\anaconda\lib\site-packages (from httpx) (1.0.2)
# Requirement already satisfied: idna in d:\anaconda\lib\site-packages (from httpx) (3.4)
# Requirement already satisfied: sniffio in d:\anaconda\lib\site-packages (from httpx) (1.2.0)
# Requirement already satisfied: h11<0.15,>=0.13 in d:\anaconda\lib\site-packages (from httpcore==1.*->httpx) (0.14.0)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: erniebot in d:\anaconda\lib\site-packages (0.4.0)
# Requirement already satisfied: aiohttp in d:\anaconda\lib\site-packages (from erniebot) (3.8.3)
# Requirement already satisfied: bce-python-sdk in d:\anaconda\lib\site-packages (from erniebot) (0.8.97)
# Requirement already satisfied: colorlog in d:\anaconda\lib\site-packages (from erniebot) (6.8.0)
# Requirement already satisfied: jsonschema>=4.19 in d:\anaconda\lib\site-packages (from erniebot) (4.20.0)
# Requirement already satisfied: requests>=2.20 in d:\anaconda\lib\site-packages (from erniebot) (2.31.0)
# Requirement already satisfied: typing-extensions in d:\anaconda\lib\site-packages (from erniebot) (4.7.1)
# Requirement already satisfied: attrs>=22.2.0 in d:\anaconda\lib\site-packages (from jsonschema>=4.19->erniebot) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\anaconda\lib\site-packages (from jsonschema>=4.19->erniebot) (2023.11.2)
# Requirement already satisfied: referencing>=0.28.4 in d:\anaconda\lib\site-packages (from jsonschema>=4.19->erniebot) (0.32.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\anaconda\lib\site-packages (from jsonschema>=4.19->erniebot) (0.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests>=2.20->erniebot) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests>=2.20->erniebot) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests>=2.20->erniebot) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests>=2.20->erniebot) (2023.7.22)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\anaconda\lib\site-packages (from aiohttp->erniebot) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in d:\anaconda\lib\site-packages (from aiohttp->erniebot) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in d:\anaconda\lib\site-packages (from aiohttp->erniebot) (1.8.1)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\anaconda\lib\site-packages (from aiohttp->erniebot) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in d:\anaconda\lib\site-packages (from aiohttp->erniebot) (1.2.0)
# Requirement already satisfied: pycryptodome>=3.8.0 in d:\anaconda\lib\site-packages (from bce-python-sdk->erniebot) (3.19.0)
# Requirement already satisfied: future>=0.6.0 in d:\anaconda\lib\site-packages (from bce-python-sdk->erniebot) (0.18.3)
# Requirement already satisfied: six>=1.4.0 in d:\anaconda\lib\site-packages (from bce-python-sdk->erniebot) (1.16.0)
# Requirement already satisfied: colorama in d:\anaconda\lib\site-packages (from colorlog->erniebot) (0.4.6)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: zhipuai in d:\anaconda\lib\site-packages (1.0.7)
# Requirement already satisfied: requests in d:\anaconda\lib\site-packages (from zhipuai) (2.31.0)
# Requirement already satisfied: PyJWT in d:\anaconda\lib\site-packages (from zhipuai) (2.4.0)
# Requirement already satisfied: dataclasses in d:\anaconda\lib\site-packages (from zhipuai) (0.6)
# Requirement already satisfied: cachetools in d:\anaconda\lib\site-packages (from zhipuai) (5.3.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in d:\anaconda\lib\site-packages (from requests->zhipuai) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\anaconda\lib\site-packages (from requests->zhipuai) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in d:\anaconda\lib\site-packages (from requests->zhipuai) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in d:\anaconda\lib\site-packages (from requests->zhipuai) (2023.7.22)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: PyYAML in d:\anaconda\lib\site-packages (6.0)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# 导入Agently的配置文件（中国大陆模型）

# %%
import Agently

agent_factory = Agently.AgentFactory()
agent_factory\
    .set_settings("current_model", "ZhipuAI")\
    .set_settings("model.ZhipuAI.auth", { "api_key": "" })

# %% [markdown]
# 开始测试Agently_zhipu_agent

# %% [markdown]
# 测试1（文本传输）

# %%
agent = agent_factory.create_agent()
agent.input("Print 'It works'.").start()
# Out:
# ' It works.'

# %% [markdown]
# 测试2（简单对话）

# %%
agent_factory = Agently.AgentFactory(is_debug=True)
agent_factory\
.set_settings("model.ZhipuAI.auth", { "api_key": "" })
agent = agent_factory.create_agent("test_agent")
agent.active_session("test_session")
while True:
    user_input = input("[YOU]: ")
    if user_input == "#exit":
        break
    response = agent.input(user_input).start()
    print("[AGENT]: ", response)
agent.stop_session()
# Out:
# Exception in thread Thread-27 (start_in_theard):
# Traceback (most recent call last):
#   File "D:\Anaconda\Lib\threading.py", line 1038, in _bootstrap_inner
#     self.run()
#   File "D:\Anaconda\Lib\threading.py", line 975, in run
#     self._target(*self._args, **self._kwargs)
#   File "D:\Anaconda\Lib\site-packages\Agently\Agent\Agent.py", line 201, in start_in_theard
#     reply = asyncio.get_event_loop().run_until_complete(self.start_async(request_type))
#             ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\asyncio\base_events.py", line 653, in run_until_complete
#     return future.result()
#            ^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\Agently\Agent\Agent.py", line 151, in start_async
#     event_generator = await self.request.get_event_generator(request_type)
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\Agently\Request\Request.py", line 104, in get_event_generator
#     response_generator = request_plugin_export["request_model"](request_data)
#                          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\Agently\plugins\request\OpenAI.py", line 203, in request_model
#     return self.request_gpt(request_data)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\Agently\plugins\request\OpenAI.py", line 183, in request_gpt
#     client = self._create_client()
#              ^^^^^^^^^^^^^^^^^^^^^
#   File "D:\Anaconda\Lib\site-packages\Agently\plugins\request\OpenAI.py", line 30, in _create_client
#     raise Exception("[Request] OpenAI require api_key. use .set_auth({ 'api_key': '<Your-API-Key>' }) to set it.")
# Exception: [Request] OpenAI require api_key. use .set_auth({ 'api_key': '<Your-API-Key>' }) to set it.
# [Request Data]
#  {
#     "stream": true,
#     "messages": [
#         {
#             "role": "user",
#             "content": "what did we say?"
#         }
#     ],
#     "model": "gpt-3.5-turbo"
# }
# ---------------------------------------------------------------------------
# Empty                                     Traceback (most recent call last)
# Cell In[10], line 10
#       8     if user_input == "#exit":
#       9         break
# ---> 10     response = agent.input(user_input).start()
#      11     print("[AGENT]: ", response)
#      12 agent.stop_session()
#
# File D:\Anaconda\Lib\site-packages\Agently\Agent\Agent.py:206, in Agent.start(self, request_type)
#     204 theard.start()
#     205 theard.join()
# --> 206 reply = reply_queue.get_nowait()
#     207 return reply
#
# File D:\Anaconda\Lib\queue.py:199, in Queue.get_nowait(self)
#     193 def get_nowait(self):
#     194     '''Remove and return an item from the queue without blocking.
#     195
#     196     Only get an item if one is immediately available. Otherwise
#     197     raise the Empty exception.
#     198     '''
# --> 199     return self.get(block=False)
#
# File D:\Anaconda\Lib\queue.py:168, in Queue.get(self, block, timeout)
#     166 if not block:
#     167     if not self._qsize():
# --> 168         raise Empty
#     169 elif timeout is None:
#     170     while not self._qsize():
#
# Empty:
